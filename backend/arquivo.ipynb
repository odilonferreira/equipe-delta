# %%
import pandas as pd
import numpy
df = pd.read_csv('./data/satisfacao_5_1.csv')
df.dropna(inplace=True)
novo = pd.DataFrame()
novo['versao'] = df['versao']
novo['grauSatisfacao'] = df['grauSatisfacao']

novo.groupby(['versao', 'grauSatisfacao']).count().head()
# Out:
# Empty DataFrame
# Columns: []
# ...
